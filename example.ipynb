# %% [markdown]
# <a href="https://colab.research.google.com/github/umirovazarina/week1_lab/blob/main/example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Please update the information, and submit your work

# %%
my_name = "Zarina"

# %%
my_enrollment_number = "A85204925051"

# %%
my_hobby = "Diving, Reading Books"

# %%
print("Hello, my name is {}, and my my enrollment number is {}. I like {}.".format(my_name, my_enrollment_number, my_hobby))
# Out:
# Hello, my name is Zarina, and my my enrollment number is A85204925051. I like Diving, Reading Books.
